# %%
import os
import pandas as pd

# %%
def create_csv(data_dir, output_csv):
    data = []
    
    for class_name in os.listdir(data_dir):
        class_path = os.path.join(data_dir, class_name)
        if os.path.isdir(class_path):
            for img_name in os.listdir(class_path):
                img_path = os.path.join(class_path, img_name)
                data.append({
                    'image_path': img_path,
                    'class': class_name
                })
    
    df = pd.DataFrame(data)
    df.to_csv(output_csv, index=False)
    print(f"CSV saved to {output_csv}")

# %%
train_dir = r"M:\GitHub\plnat-disease-classifiacation\datasets\datasets\vipoooool\new-plant-diseases-dataset\versions\2\New Plant Diseases Dataset(Augmented)\New Plant Diseases Dataset(Augmented)\train"
valid_dir = r"M:\GitHub\plnat-disease-classifiacation\datasets\datasets\vipoooool\new-plant-diseases-dataset\versions\2\New Plant Diseases Dataset(Augmented)\New Plant Diseases Dataset(Augmented)\valid"

train_csv = "train_data.csv"
test_csv = "test_data.csv"

create_csv(train_dir, train_csv)
create_csv(valid_dir, test_csv)
# Out:
# CSV saved to train_data.csv
# CSV saved to test_data.csv

# %%
df=pd.read_csv("train_data.csv")
df
# Out:
#                                               image_path  \
# 0      M:\GitHub\plnat-disease-classifiacation\datase...
# 1      M:\GitHub\plnat-disease-classifiacation\datase...
# 2      M:\GitHub\plnat-disease-classifiacation\datase...
# 3      M:\GitHub\plnat-disease-classifiacation\datase...
# 4      M:\GitHub\plnat-disease-classifiacation\datase...
# ...                                                  ...
# 70290  M:\GitHub\plnat-disease-classifiacation\datase...
# 70291  M:\GitHub\plnat-disease-classifiacation\datase...
# 70292  M:\GitHub\plnat-disease-classifiacation\datase...
# 70293  M:\GitHub\plnat-disease-classifiacation\datase...
# 70294  M:\GitHub\plnat-disease-classifiacation\datase...
#
#                                         class
# 0                          Apple___Apple_scab
# 1                          Apple___Apple_scab
# 2                          Apple___Apple_scab
# 3                          Apple___Apple_scab
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
class_counts = df['class'].value_counts()
print("Class distribution:\n", class_counts)
# Out:
# Class distribution:
#  class
# Soybean___healthy                                     2022
# Apple___Apple_scab                                    2016
# Orange___Haunglongbing_(Citrus_greening)              2010
# Apple___healthy                                       2008
# Pepper,_bell___healthy                                1988
# Apple___Black_rot                                     1987
# Tomato___Tomato_Yellow_Leaf_Curl_Virus                1961
# Potato___Early_blight                                 1939
# Potato___Late_blight                                  1939
# Tomato___healthy                                      1926
# Tomato___Early_blight                                 1920
# Grape___Esca_(Black_Measles)                          1920
# Pepper,_bell___Bacterial_spot                         1913
# Corn_(maize)___Northern_Leaf_Blight                   1908
# Corn_(maize)___Common_rust_                           1907
# ...

# %%
plt.figure(figsize=(12, 6))
class_counts.plot(kind='bar')
plt.title('Class Distribution in Training Dataset')
plt.xlabel('Class')
plt.ylabel('Number of Images')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
